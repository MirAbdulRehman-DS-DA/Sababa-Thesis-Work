# %% [markdown]
# Bismillah Alrehman Nirraheem

# %%
# Importing Libraries

from rdkit import Chem
from rdkit.Chem import PandasTools
import pandas as pd
import os

# %%
# Load the SDF file
Atorvastatin_sdf_file = 'data\Group A\Atorvastatin\SDF\Atorvastatin-DB01076.sdf' # initializing Variable to store location for Atorvastatin
Metformin_sdf_file = 'data\Group A\Metformin\SDF\Metformin-DB00331.sdf' # initializing Variable to store location for Metformin
Omeprazole_sdf_file = 'data\Group A\Omeprazole\SDF\Omeprazole-DB00338.sdf' # initializing Variable to store location for Omeprazole

suppl = Chem.SDMolSupplier(Atorvastatin_sdf_file)
suppl = Chem.SDMolSupplier(Metformin_sdf_file)
suppl = Chem.SDMolSupplier(Omeprazole_sdf_file)

# Convert to Pandas DataFrame
Atorvastatin_df = PandasTools.LoadSDF(Atorvastatin_sdf_file)
Metformin_df = PandasTools.LoadSDF(Metformin_sdf_file)
Omeprazole_df = PandasTools.LoadSDF(Omeprazole_sdf_file)

# Display the DataFrame
# print(Atorvastatin_df.head())
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15732\1639749900.py:2: SyntaxWarning: invalid escape sequence '\G'
#   Atorvastatin_sdf_file = 'data\Group A\Atorvastatin\SDF\Atorvastatin-DB01076.sdf' # initializing Variable to store location for Atorvastatin
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15732\1639749900.py:3: SyntaxWarning: invalid escape sequence '\G'
#   Metformin_sdf_file = 'data\Group A\Metformin\SDF\Metformin-DB00331.sdf' # initializing Variable to store location for Metformin
# C:\Users\abdul\AppData\Local\Temp\ipykernel_15732\1639749900.py:4: SyntaxWarning: invalid escape sequence '\G'
# ...

# %%
# Merge DataFrames
merged_df = pd.concat([Atorvastatin_df, Metformin_df, Omeprazole_df], ignore_index=True)

merged_df.head()
# Out:
#   DATABASE_ID DATABASE_NAME  \
# 0     DB01076      drugbank
# 1     DB00331      drugbank
# 2     DB00338      drugbank
#
#                                               SMILES  \
# 0  CC(C)C1=C(C(=O)NC2=CC=CC=C2)C(=C(N1CC[C@@H](O)...
# 1                                  CN(C)C(=N)NC(N)=N
# 2   COC1=CC2=C(C=C1)N=C(N2)S(=O)CC1=NC=C(C)C(OC)=C1C
#
#                                     INCHI_IDENTIFIER  \
# 0  InChI=1S/C33H35FN2O5/c1-21(2)31-30(33(41)35-25...
# 1  InChI=1S/C4H11N5/c1-9(2)4(7)8-3(5)6/h1-2H3,(H5...
# 2  InChI=1S/C17H19N3O3S/c1-10-8-18-15(11(2)16(10)...
#
#                      INCHI_KEY      FORMULA MOLECULAR_WEIGHT     EXACT_MASS  \
# 0  XUKUURHRXDUEBC-KAYWLYCHSA-N  C33H35FN2O5         558.6398  558.253000445
# 1  XZWYZXLIPXDOLR-UHFFFAOYSA-N      C4H11N5         129.1636  129.101445377
# 2  SUBDBMMJDZJVOS-UHFFFAOYSA-N  C17H19N3O3S          345.416  345.114712179
#
#   JCHEM_ACCEPTOR_COUNT JCHEM_ATOM_COUNT  ... DRUGBANK_ID  \
# ...

# %%
merged_df.to_csv('merged.csv',index=False)
